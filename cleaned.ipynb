# %%
import pandas as pd

# %%
input_file = 'Output.csv'
df = pd.read_csv(input_file)

# %%
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#       Movie Id                  Movie Name             Director  \
# 0            0                interstellar    Christopher Nolan
# 1            1               thedarkknight    Christopher Nolan
# 2            2  theekenruddhaswasrajasthan    Joydeep Mukherjee
# 3            3  lagaanonceuponatimeinindia   Ashutosh Gowariker
# 4            4                     ramsetu      Abhishek Sharma
# ...        ...                         ...                  ...
# 2091      2126                       sawii  Darren Lynn Bousman
# 2092      2127           10cloverfieldlane     Dan Trachtenberg
# 2093      2128             jackassthemovie        Jeff Tremaine
# 2094      2129                   lightsout    David F. Sandberg
# 2095      2130         paranormalactivity3          Henry Joost
#
#                      Lead_Actor              Lead_Actress  Runtime (.)  \
# 0     Matthew David McConaughey  Anne Jacqueline Hathaway          169
# 1                Christian Bale             Anne Hathaway          152
# 2           Anirban Chakrabarti              Naomi Harris          121
# 3                    Aamir Khan               Gracy Singh          224
# 4                  Akshay Kumar      Jacqueline Fernandez          143
# ...                         ...                       ...          ...
# 2091          Abhishek Bachchan         Shirley Henderson           93
# 2092             Patrick Wilson              Rani Mukerji          103
# 2093            Donnie Wahlberg               Flora Cross           85
# 2094               John Goodman                Adam Scott           81
# 2095           Johnny Knoxville           Kristen Stewart           83
#
#       IMDb_Rating Language     Animated  Action  ...  Trailer Views  \
# 0             8.7  English  Live Action     1.0  ...     36314005.0
# 1             9.0  English  Live Action     1.0  ...    180000000.0
# 2             6.7  Bengali  Live Action     0.0  ...      1419093.0
# 3             8.1    Hindi  Live Action     0.0  ...     10460532.0
# 4             5.2    Hindi  Live Action     0.0  ...     41621819.0
# ...           ...      ...          ...     ...  ...            ...
# 2091          6.6    Hindi  Live Action     0.0  ...     42061546.0
# 2092          7.2  English  Live Action     0.0  ...     74493329.0
# 2093          6.6  English  Live Action     1.0  ...     38980321.0
# 2094          6.3  English  Live Action     NaN  ...    108096770.0
# 2095          5.8  English  Live Action     0.0  ...     74738505.0
#
#       Trailer Likes (K)  Follower Count (Lead Actor)  \
# 0                   202                      9000000
# 1                   185                       422000
# 2                    92                        15000
# 3                    86                      2000000
# 4                   796                     67000000
# ...                 ...                          ...
# 2091               3952                      8000000
# 2092               4207                          117
# 2093               3998                     26000000
# 2094               4349                      9000000
# 2095               4155                       104000
#
#       Follower Count (Lead Actress)  Follower Count (Director)  \
# 0                          31000000                      97000
# 1                          31000000                      97000
# 2                            467000                       2064
# 3                            146000                        196
# 4                          69000000                     209000
# ...                             ...                        ...
# 2091                         387000                        391
# 2092                        6000000                     342000
# 2093                       22000000                      10000
# 2094                       15000000                     158000
# 2095                       75000000                     148000
#
#       Popularity of Actor Male (POAM)  Popularity of Actress Female (POAF)  \
# 0                                0.60                                 0.29
# 1                                0.32                                 0.39
# 2                                0.50                                 0.23
# 3                                0.13                                 0.23
# 4                                0.33                                 0.46
# ...                               ...                                  ...
# 2091                             0.42                                 0.37
# 2092                             0.58                                 0.53
# 2093                             0.40                                 0.80
# 2094                             0.78                                 0.37
# 2095                             0.75                                 0.40
#
#       Popularity of Director (POD)    CSS  Verdict (Given)
# 0                             0.80  0.300      Blockbuster
# 1                             0.80  0.400              Hit
# 2                             0.50  0.238         Superhit
# 3                             0.43  0.350      Blockbuster
# 4                             0.25  0.350             Flop
# ...                            ...    ...              ...
# 2091                          0.48  0.300          Average
# 2092                          0.55  0.450          Average
# 2093                          0.60  0.500          Average
# 2094                          0.86  0.300      Blockbuster
# 2095                          0.56  0.350      Blockbuster
#
# [2096 rows x 58 columns]

# %%
df_cleaned = df.dropna()

print("\nDataFrame after removing rows with at least one blank value:")
print(df_cleaned)
# Out:
# DataFrame after removing rows with at least one blank value:
#       Movie Id                  Movie Name             Director  \
# 0            0                interstellar    Christopher Nolan
# 1            1               thedarkknight    Christopher Nolan
# 2            2  theekenruddhaswasrajasthan    Joydeep Mukherjee
# 3            3  lagaanonceuponatimeinindia   Ashutosh Gowariker
# 4            4                     ramsetu      Abhishek Sharma
# ...        ...                         ...                  ...
# 2089      2124                 dummaarodum          Rohan Sippy
# 2091      2126                       sawii  Darren Lynn Bousman
# 2092      2127           10cloverfieldlane     Dan Trachtenberg
# 2093      2128             jackassthemovie        Jeff Tremaine
# 2095      2130         paranormalactivity3          Henry Joost
#
#                      Lead_Actor              Lead_Actress  Runtime (.)  \
# 0     Matthew David McConaughey  Anne Jacqueline Hathaway          169
# 1                Christian Bale             Anne Hathaway          152
# 2           Anirban Chakrabarti              Naomi Harris          121
# 3                    Aamir Khan               Gracy Singh          224
# 4                  Akshay Kumar      Jacqueline Fernandez          143
# ...                         ...                       ...          ...
# 2089           Jessica Chastain            Joanne Whalley          128
# 2091          Abhishek Bachchan         Shirley Henderson           93
# 2092             Patrick Wilson              Rani Mukerji          103
# 2093            Donnie Wahlberg               Flora Cross           85
# 2095           Johnny Knoxville           Kristen Stewart           83
#
#       IMDb_Rating Language     Animated  Action  ...  Trailer Views  \
# 0             8.7  English  Live Action     1.0  ...     36314005.0
# 1             9.0  English  Live Action     1.0  ...    180000000.0
# 2             6.7  Bengali  Live Action     0.0  ...      1419093.0
# 3             8.1    Hindi  Live Action     0.0  ...     10460532.0
# 4             5.2    Hindi  Live Action     0.0  ...     41621819.0
# ...           ...      ...          ...     ...  ...            ...
# 2089          6.2  English  Live Action     0.0  ...     25004927.0
# 2091          6.6    Hindi  Live Action     0.0  ...     42061546.0
# 2092          7.2  English  Live Action     0.0  ...     74493329.0
# 2093          6.6  English  Live Action     1.0  ...     38980321.0
# 2095          5.8  English  Live Action     0.0  ...     74738505.0
#
#       Trailer Likes (K)  Follower Count (Lead Actor)  \
# 0                   202                      9000000
# 1                   185                       422000
# 2                    92                        15000
# 3                    86                      2000000
# 4                   796                     67000000
# ...                 ...                          ...
# 2089               4238                        26000
# 2091               3952                      8000000
# 2092               4207                          117
# 2093               3998                     26000000
# 2095               4155                       104000
#
#       Follower Count (Lead Actress)  Follower Count (Director)  \
# 0                          31000000                      97000
# 1                          31000000                      97000
# 2                            467000                       2064
# 3                            146000                        196
# 4                          69000000                     209000
# ...                             ...                        ...
# 2089                         493000                    2000000
# 2091                         387000                        391
# 2092                        6000000                     342000
# 2093                       22000000                      10000
# 2095                       75000000                     148000
#
#       Popularity of Actor Male (POAM)  Popularity of Actress Female (POAF)  \
# 0                                0.60                                 0.29
# 1                                0.32                                 0.39
# 2                                0.50                                 0.23
# 3                                0.13                                 0.23
# 4                                0.33                                 0.46
# ...                               ...                                  ...
# 2089                             0.16                                 0.14
# 2091                             0.42                                 0.37
# 2092                             0.58                                 0.53
# 2093                             0.40                                 0.80
# 2095                             0.75                                 0.40
#
#       Popularity of Director (POD)    CSS  Verdict (Given)
# 0                             0.80  0.300      Blockbuster
# 1                             0.80  0.400              Hit
# 2                             0.50  0.238         Superhit
# 3                             0.43  0.350      Blockbuster
# 4                             0.25  0.350             Flop
# ...                            ...    ...              ...
# 2089                          0.33  0.400      Blockbuster
# 2091                          0.48  0.300          Average
# 2092                          0.55  0.450          Average
# 2093                          0.60  0.500          Average
# 2095                          0.56  0.350      Blockbuster
#
# [1894 rows x 58 columns]

# %%
output_file = 'output_merged_cleaned.csv'
df_cleaned.to_csv(output_file, index=False)

print(f"\nCleaned DataFrame saved to {output_file}")
# Out:
# Cleaned DataFrame saved to output_merged_cleaned.csv
